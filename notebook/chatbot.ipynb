# %%
import joblib
from sentence_transformers import SentenceTransformer, util

qa_pairs = [
    {"question": "What is an insurance policy?", 
    "answer": "An insurance policy is a legal agreement between you and the insurance company. It promises to help you financially if something bad happens, like illness, accident, or damage."},

    {"question": "Why should I buy insurance?", 
    "answer": "Insurance helps protect you from big money losses. It gives peace of mind during emergencies like accidents, health issues, or damage to your home or vehicle."},

    {"question": "What types of insurance are there?", 
    "answer": "There are many types like health insurance, life insurance, motor (vehicle) insurance, and home insurance."},

    {"question": "How do I buy an insurance policy?", 
    "answer": "You can buy it online on the insurer’s website or through an agent. You fill a form, submit documents, and pay the premium."},

    {"question": "What is a premium?", 
    "answer": "A premium is the money you pay to the insurance company regularly (like yearly or monthly) to keep your policy active."},

    {"question": "What happens after I buy insurance?", 
    "answer": "You’ll get a policy document with all the details. Keep it safe. You can claim when something covered in the policy happens."},

    {"question": "Can I cancel my insurance policy?", 
    "answer": "Yes, you can cancel it. Most policies offer a 15-day free-look period to cancel and get a refund."},

    {"question": "What is a claim in insurance?", 
    "answer": "A claim is when you ask the insurance company to pay for something covered in your policy, like a hospital bill or car repair."},

    {"question": "Is insurance only for rich people?", 
    "answer": "No. Insurance is for everyone. It helps protect your money no matter your income."},
    
    # Home Insurance 

    {"question": "What is home insurance?", 
     "answer": "Home insurance protects your house and things inside it if they are damaged or stolen."},

    {"question": "Does home insurance cover earthquakes?", 
     "answer": "No, normal home insurance doesn’t cover earthquakes. You need to buy extra coverage for that."},

    {"question": "What is the difference between contents insurance and building insurance?", 
     "answer": "Building insurance protects the house structure. Contents insurance protects your things inside the house."},

    {"question": "Is home insurance mandatory?", 
     "answer": "It’s not required by law, but banks may ask for it if you take a home loan."},

    {"question": "Does home insurance cover flood damage?", 
     "answer": "Usually no. You need to buy separate flood insurance for that."},

    {"question": "Can I cover my electronics in home insurance?", 
     "answer": "Yes, some policies let you cover electronics like TVs and computers too."},

    {"question": "How do I claim home insurance?", 
     "answer": "Call your insurer, submit documents and photos of the damage, and follow their process."},

    #Health Insurance

    {"question": "What is health insurance?", 
     "answer": "Health insurance helps you pay hospital and doctor bills when you get sick or hurt."},

    {"question": "What is a pre-existing disease?", 
     "answer": "A pre-existing disease is a health problem you had before buying the policy."},

    {"question": "What is a waiting period?", 
     "answer": "It’s the time you must wait before your insurance starts covering some treatments."},

    {"question": "Is maternity covered under health insurance?", 
     "answer": "Some plans cover maternity, but you may need to wait a few years before using it."},

    {"question": "What is cashless treatment?", 
     "answer": "Cashless treatment means the insurance company pays the hospital directly, so you don’t need to pay first."},

    {"question": "Can I use health insurance for regular check-ups?", 
     "answer": "Some plans cover health check-ups once a year. Check your policy details."},

    {"question": "Are alternative treatments like Ayurveda covered?", 
     "answer": "Yes, many plans cover AYUSH treatments like Ayurveda, Yoga, Unani, Siddha, and Homeopathy."},

    # Life Insurance

    {"question": "What is life insurance?", 
     "answer": "Life insurance gives money to your family if something happens to you."},

    {"question": "What is term life insurance?", 
     "answer": "It’s a plan that covers you for a few years. If you die during that time, your family gets money."},

    {"question": "What is whole life insurance?", 
     "answer": "Whole life insurance covers you your entire life and builds some savings too."},

    {"question": "Do I get money if I survive the policy term?", 
     "answer": "Only some plans return money if you survive. Term plans usually don’t give money if you live."},

    {"question": "Can I buy life insurance for my parents?", 
     "answer": "Yes, you can buy a policy for your parents with their consent."},

    {"question": "What is a nominee in life insurance?", 
     "answer": "A nominee is the person who will get the money from your life insurance if you pass away."},

    {"question": "How much life insurance do I need?", 
     "answer": "It depends on your income, expenses, and your family’s future needs."},

    # Motor Insurance
    
    {"question": "What is motor insurance?", 
     "answer": "Motor insurance pays for damage to your car or bike and protects you from accident-related costs."},

    {"question": "Is motor insurance required by law?", 
     "answer": "Yes, at least third-party insurance is legally required to drive on the road."},

    {"question": "What is third-party insurance?", 
     "answer": "It covers damage you cause to others but doesn’t cover your own vehicle."},

    {"question": "What is comprehensive motor insurance?", 
     "answer": "It covers both your vehicle and damage caused to others."},

    {"question": "Can I transfer my insurance to a new owner?", 
     "answer": "Yes, you can transfer the policy when you sell your car or bike."},

    {"question": "What is IDV in motor insurance?", 
     "answer": "IDV means Insured Declared Value. It’s the current value of your vehicle that your insurer will pay if it’s stolen or totaled."},

    {"question": "How do I claim motor insurance after an accident?", 
     "answer": "Call your insurer, take pictures, file an FIR if needed, and submit the required documents."}
]

# %%
# load the pretrained mdoel
model = SentenceTransformer("all-MiniLM-L6-v2")
questions = [question["question"] for question in qa_pairs]
question_embeddings = model.encode(questions)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# c:\Users\ragu\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:144: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ragu\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
# create pipeline
model = {
    "qa_pairs": qa_pairs,
    "question_embeddings": question_embeddings,
    "model_name": "all-MiniLM-L6-v2"
}

# %%
# dump chatbot
joblib.dump(model, "chatbot_model.pkl")
# Out:
# ['chatbot_model.pkl']

# %%
model = joblib.load("C:/Users/ragu/capstone_pj/models/chatbot_model.pkl")
print(type(model))
print(model.keys())
# Out:
# <class 'dict'>
# dict_keys(['qa_pairs', 'question_embeddings', 'model_name'])

# %%
# Load the chatbot model
model_data = joblib.load("C:/Users/ragu/capstone_pj/models/chatbot_model.pkl")

# Unpack components
qa_pairs = model_data["qa_pairs"]
question_embeddings = model_data["question_embeddings"]
model_name = model_data["model_name"]

# Reload the transformer model
model = SentenceTransformer(model_name)

# Chat function
def chat_with_bot(user_input):
    input_embedding = model.encode(user_input)
    similarities = util.cos_sim(input_embedding, question_embeddings)[0]
    best_match_idx = similarities.argmax()
    return qa_pairs[best_match_idx]["answer"]

# Interactive test
while True:
    user_input = input("You: ")
    if user_input.lower() in ["exit", "quit"]:
        print("Bot: Goodbye!")
        break
    response = chat_with_bot(user_input)
    print("Bot:", response)
# Out:
# Bot: Motor insurance pays for damage to your car or bike and protects you from accident-related costs.
# Bot: It covers both your vehicle and damage caused to others.
# Bot: Goodbye!
